# %% [markdown]
# ## Выделение области лица и контуров губ

# %%
import cv2
import pytube as pt
import numpy as np
import moviepy as mp
import dlib

# %%
cap = cv2.VideoCapture(0)
detector = dlib.get_frontal_face_detector()
predictor = dlib.shape_predictor('../Models/shape_predictor_68_face_landmarks.dat')
WIDTH = cap.get(3)
HEIGHT = cap.get(4)

while True:
    ret, frame = cap.read()
    if not ret:
        break
    
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    faces = detector(gray)
    
    for face in faces:
        x1, y1 = face.left(), face.top()
        x2, y2 = face.right(), face.bottom()
        
        landmarks = predictor(gray, face)
        
        x_min, y_min, x_max, y_max = WIDTH, HEIGHT, 0, 0 
        for i in range(48, 60):
            if 
            x, y = landmarks.part(i).x, landmarks.part(i).y
            cv2.circle(frame, (x, y), 2, (0, 0, 255))
        
        cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)
        
        
    cv2.imshow('frame', frame)
    
    if cv2.waitKey(1) & 0xff == ord('q'):
        break
        
cap.release()
cv2.destroyAllWindows()
# Out:
# [point(286, 367) point(298, 358) point(310, 352) point(320, 355)
#  point(330, 352) point(343, 358) point(356, 367) point(344, 375)
#  point(331, 379) point(320, 380) point(310, 379) point(299, 375)]
# [point(288, 367) point(301, 357) point(312, 351) point(321, 354)
#  point(331, 351) point(344, 356) point(357, 366) point(345, 374)
#  point(333, 378) point(322, 379) point(312, 378) point(301, 374)]
# [point(289, 366) point(302, 355) point(313, 349) point(323, 352)
#  point(333, 349) point(345, 355) point(358, 364) point(346, 372)
#  point(334, 376) point(324, 377) point(314, 376) point(302, 373)]
# [point(290, 364) point(303, 354) point(314, 348) point(324, 351)
#  point(334, 348) point(347, 354) point(360, 363) point(347, 370)
#  point(335, 374) point(324, 375) point(314, 374) point(303, 371)]
# [point(291, 363) point(304, 352) point(316, 346) point(325, 349)
#  point(335, 346) point(348, 351) point(360, 361) point(348, 369)
#  point(336, 372) point(325, 373) point(316, 373) point(304, 370)]
# [point(293, 362) point(304, 352) point(316, 345) point(326, 348)
#  point(335, 345) point(348, 350) point(360, 360) point(348, 368)
#  point(336, 372) point(327, 373) point(317, 372) point(305, 369)]
# [point(296, 361) point(307, 350) point(319, 344) point(328, 346)
#  point(337, 343) point(349, 350) point(361, 360) point(350, 367)
#  point(338, 370) point(328, 371) point(318, 371) point(307, 368)]
# [point(296, 360) point(307, 349) point(318, 343) point(328, 345)
#  point(337, 342) point(349, 348) point(361, 359) point(349, 367)
#  point(338, 371) point(328, 372) point(318, 371) point(307, 368)]
# [point(297, 360) point(308, 349) point(319, 342) point(329, 344)
#  point(337, 341) point(349, 348) point(361, 359) point(350, 367)
#  point(339, 371) point(330, 372) point(319, 371) point(308, 368)]
# [point(297, 360) point(308, 349) point(319, 342) point(329, 344)
#  point(338, 342) point(350, 348) point(361, 359) point(350, 368)
#  point(339, 371) point(329, 372) point(319, 371) point(309, 368)]
# [point(297, 361) point(308, 349) point(319, 342) point(329, 344)
#  point(337, 342) point(349, 348) point(361, 361) point(350, 370)
#  point(338, 375) point(329, 375) point(319, 374) point(309, 371)]
# [point(297, 363) point(307, 349) point(319, 342) point(329, 344)
#  point(337, 341) point(349, 348) point(360, 362) point(350, 373)
#  point(339, 378) point(329, 379) point(319, 378) point(308, 373)]
# [point(297, 363) point(306, 349) point(318, 342) point(328, 344)
#  point(337, 341) point(350, 348) point(361, 362) point(350, 374)
#  point(338, 379) point(328, 380) point(318, 379) point(307, 374)]
# [point(296, 360) point(307, 350) point(319, 344) point(329, 347)
#  point(337, 344) point(350, 349) point(362, 359) point(350, 368)
#  point(338, 371) point(329, 372) point(319, 371) point(308, 368)]
# [point(295, 359) point(307, 350) point(319, 344) point(328, 347)
#  point(337, 344) point(349, 350) point(363, 359) point(350, 367)
#  point(338, 371) point(329, 371) point(319, 370) point(307, 367)]
# [point(296, 363) point(307, 353) point(318, 346) point(327, 349)
#  point(336, 346) point(349, 352) point(362, 362) point(349, 370)
#  point(337, 374) point(328, 374) point(319, 374) point(308, 371)]
# [point(296, 365) point(306, 353) point(318, 346) point(328, 349)
#  point(337, 346) point(349, 353) point(361, 365) point(350, 375)
#  point(338, 380) point(328, 381) point(318, 380) point(307, 376)]
# [point(294, 363) point(306, 353) point(318, 347) point(328, 349)
#  point(337, 347) point(349, 353) point(361, 363) point(350, 373)
#  point(338, 378) point(328, 379) point(318, 378) point(306, 373)]
# [point(294, 362) point(306, 353) point(318, 347) point(328, 350)
#  point(336, 347) point(349, 353) point(363, 361) point(350, 370)
#  point(337, 373) point(328, 374) point(318, 373) point(307, 370)]
# [point(294, 362) point(306, 354) point(318, 347) point(328, 350)
#  point(336, 347) point(349, 353) point(363, 362) point(350, 370)
#  point(338, 374) point(328, 375) point(318, 374) point(307, 371)]
# [point(294, 364) point(306, 355) point(318, 349) point(328, 352)
#  point(336, 348) point(349, 354) point(362, 364) point(350, 372)
#  point(338, 376) point(329, 377) point(318, 376) point(307, 373)]
# [point(294, 366) point(306, 355) point(317, 348) point(327, 350)
#  point(336, 348) point(349, 354) point(361, 365) point(350, 376)
#  point(338, 381) point(328, 382) point(318, 381) point(307, 377)]
# [point(295, 366) point(306, 356) point(318, 348) point(327, 351)
#  point(336, 348) point(348, 354) point(360, 365) point(349, 376)
#  point(337, 381) point(328, 382) point(318, 381) point(306, 376)]
# [point(293, 364) point(305, 355) point(317, 348) point(327, 352)
#  point(337, 348) point(349, 354) point(362, 363) point(350, 372)
#  point(338, 376) point(328, 378) point(317, 377) point(306, 373)]
# [point(293, 363) point(305, 355) point(317, 348) point(327, 351)
#  point(335, 348) point(349, 354) point(362, 363) point(349, 372)
#  point(337, 375) point(328, 376) point(318, 375) point(306, 371)]
# [point(294, 365) point(306, 356) point(318, 350) point(328, 353)
#  point(336, 350) point(348, 355) point(362, 364) point(349, 372)
#  point(338, 376) point(328, 377) point(318, 376) point(307, 373)]
# [point(295, 366) point(306, 357) point(317, 350) point(327, 353)
#  point(336, 350) point(349, 356) point(362, 366) point(350, 376)
#  point(338, 381) point(328, 382) point(318, 381) point(306, 377)]
# [point(294, 367) point(305, 356) point(317, 349) point(327, 353)
#  point(336, 350) point(349, 356) point(362, 367) point(350, 379)
#  point(338, 384) point(328, 385) point(317, 383) point(305, 378)]
# [point(294, 365) point(306, 356) point(317, 350) point(327, 353)
#  point(336, 350) point(349, 355) point(362, 365) point(350, 374)
#  point(338, 379) point(328, 380) point(318, 378) point(307, 374)]
# [point(293, 364) point(305, 355) point(317, 349) point(327, 353)
#  point(336, 349) point(349, 355) point(362, 363) point(350, 372)
#  point(338, 376) point(328, 378) point(318, 376) point(306, 373)]
# [point(293, 364) point(306, 356) point(317, 350) point(327, 353)
#  point(335, 350) point(349, 355) point(362, 364) point(350, 372)
#  point(337, 376) point(328, 377) point(318, 376) point(306, 373)]
# [point(294, 365) point(306, 356) point(317, 350) point(327, 353)
#  point(336, 350) point(349, 355) point(363, 364) point(350, 373)
#  point(338, 377) point(328, 378) point(318, 377) point(307, 373)]
# [point(294, 365) point(306, 356) point(317, 350) point(327, 353)
#  point(336, 350) point(349, 355) point(362, 365) point(350, 374)
#  point(338, 379) point(328, 380) point(318, 378) point(306, 374)]
# [point(294, 366) point(306, 357) point(318, 351) point(328, 354)
#  point(336, 351) point(349, 356) point(363, 365) point(350, 375)
#  point(338, 379) point(328, 380) point(318, 379) point(306, 375)]
# [point(293, 367) point(306, 357) point(317, 351) point(327, 354)
#  point(336, 351) point(349, 356) point(361, 366) point(349, 375)
#  point(337, 379) point(328, 380) point(317, 379) point(306, 375)]
# [point(294, 367) point(306, 357) point(317, 350) point(327, 353)
#  point(336, 350) point(349, 356) point(362, 367) point(349, 378)
#  point(337, 382) point(328, 383) point(318, 382) point(306, 378)]
# [point(294, 368) point(305, 357) point(317, 350) point(327, 353)
#  point(336, 350) point(349, 356) point(362, 367) point(350, 378)
#  point(338, 383) point(328, 384) point(317, 383) point(306, 379)]
# [point(294, 367) point(305, 356) point(317, 349) point(327, 352)
#  point(337, 349) point(349, 355) point(361, 366) point(350, 377)
#  point(338, 381) point(328, 383) point(317, 381) point(306, 377)]
# [point(294, 365) point(306, 356) point(318, 350) point(328, 352)
#  point(337, 349) point(349, 355) point(363, 365) point(350, 374)
#  point(338, 378) point(329, 379) point(318, 378) point(307, 374)]
# [point(294, 365) point(306, 356) point(317, 349) point(327, 352)
#  point(335, 349) point(349, 355) point(362, 364) point(349, 372)
#  point(337, 376) point(327, 377) point(317, 376) point(307, 372)]
# [point(294, 364) point(305, 355) point(317, 349) point(327, 352)
#  point(336, 349) point(349, 354) point(363, 364) point(350, 372)
#  point(337, 376) point(328, 377) point(317, 376) point(306, 372)]
# [point(294, 364) point(306, 355) point(318, 349) point(328, 352)
#  point(336, 349) point(349, 354) point(363, 364) point(350, 372)
#  point(338, 376) point(328, 377) point(318, 376) point(306, 372)]
# [point(294, 365) point(306, 355) point(318, 349) point(328, 352)
#  point(337, 349) point(350, 355) point(363, 364) point(350, 373)
#  point(338, 377) point(328, 378) point(318, 377) point(307, 373)]
# [point(293, 366) point(306, 356) point(317, 350) point(327, 353)
#  point(336, 350) point(349, 355) point(362, 365) point(350, 374)
#  point(338, 378) point(328, 379) point(318, 378) point(306, 374)]
# [point(295, 366) point(306, 356) point(318, 350) point(328, 353)
#  point(336, 350) point(349, 356) point(363, 365) point(350, 374)
#  point(338, 378) point(328, 379) point(318, 378) point(307, 374)]
# [point(295, 366) point(306, 357) point(318, 350) point(328, 353)
#  point(337, 350) point(350, 356) point(363, 366) point(350, 375)
#  point(338, 379) point(328, 380) point(318, 379) point(307, 375)]
# [point(294, 367) point(306, 357) point(318, 350) point(327, 354)
#  point(336, 350) point(349, 356) point(363, 366) point(350, 375)
#  point(338, 379) point(328, 380) point(318, 379) point(306, 376)]
# [point(295, 368) point(306, 358) point(317, 351) point(328, 354)
#  point(337, 351) point(349, 357) point(362, 367) point(350, 376)
#  point(338, 381) point(328, 382) point(317, 380) point(307, 377)]
# [point(295, 367) point(306, 357) point(318, 351) point(328, 354)
#  point(336, 350) point(350, 356) point(362, 366) point(350, 377)
#  point(338, 381) point(328, 382) point(318, 381) point(307, 377)]
# [point(295, 367) point(306, 357) point(318, 350) point(328, 353)
#  point(337, 350) point(350, 356) point(362, 366) point(351, 376)
#  point(338, 381) point(329, 382) point(318, 380) point(307, 376)]
# [point(296, 365) point(307, 356) point(319, 350) point(328, 353)
#  point(337, 350) point(350, 356) point(363, 365) point(351, 375)
#  point(338, 379) point(329, 379) point(319, 378) point(308, 374)]
# [point(296, 366) point(307, 357) point(319, 350) point(329, 353)
#  point(338, 350) point(351, 356) point(364, 365) point(352, 374)
#  point(340, 378) point(330, 379) point(320, 378) point(308, 374)]
# [point(297, 366) point(309, 357) point(321, 350) point(331, 354)
#  point(340, 350) point(352, 356) point(364, 365) point(353, 374)
#  point(341, 378) point(331, 379) point(321, 378) point(310, 374)]
# [point(299, 366) point(311, 357) point(323, 351) point(333, 354)
#  point(342, 351) point(354, 356) point(366, 366) point(355, 375)
#  point(343, 379) point(333, 380) point(323, 379) point(311, 375)]
# [point(300, 367) point(312, 358) point(324, 351) point(334, 354)
#  point(344, 351) point(357, 357) point(369, 366) point(358, 374)
#  point(345, 379) point(335, 380) point(325, 379) point(313, 375)]
# [point(301, 368) point(314, 358) point(326, 352) point(336, 354)
#  point(345, 351) point(358, 357) point(369, 366) point(359, 375)
#  point(347, 379) point(336, 380) point(326, 379) point(314, 376)]
# [point(302, 367) point(315, 358) point(327, 352) point(337, 355)
#  point(347, 352) point(359, 358) point(371, 366) point(360, 375)
#  point(348, 379) point(338, 380) point(327, 379) point(315, 375)]
# [point(302, 368) point(315, 358) point(327, 352) point(337, 355)
#  point(347, 352) point(359, 358) point(371, 367) point(360, 375)
#  point(348, 380) point(338, 381) point(327, 380) point(315, 376)]
# [point(302, 368) point(315, 359) point(327, 352) point(337, 355)
#  point(347, 353) point(359, 358) point(371, 367) point(359, 375)
#  point(348, 380) point(338, 381) point(327, 380) point(315, 376)]
# [point(303, 368) point(315, 359) point(327, 353) point(337, 355)
#  point(346, 352) point(359, 358) point(371, 367) point(360, 375)
#  point(348, 380) point(338, 381) point(328, 380) point(316, 376)]
# [point(302, 368) point(316, 359) point(328, 353) point(338, 356)
#  point(347, 353) point(359, 358) point(371, 367) point(360, 375)
#  point(348, 380) point(338, 381) point(328, 380) point(316, 376)]
# [point(303, 369) point(316, 359) point(328, 353) point(338, 356)
#  point(348, 353) point(359, 359) point(371, 368) point(360, 376)
#  point(349, 380) point(339, 381) point(328, 380) point(316, 377)]
# [point(303, 369) point(316, 360) point(328, 354) point(338, 357)
#  point(347, 354) point(360, 359) point(371, 368) point(360, 377)
#  point(348, 382) point(338, 383) point(328, 382) point(316, 378)]
# [point(302, 370) point(315, 361) point(328, 354) point(338, 357)
#  point(347, 354) point(359, 360) point(371, 370) point(360, 380)
#  point(348, 385) point(338, 386) point(327, 385) point(315, 380)]
# [point(303, 371) point(315, 360) point(327, 354) point(337, 357)
#  point(346, 354) point(359, 360) point(370, 371) point(360, 384)
#  point(348, 390) point(338, 391) point(327, 389) point(315, 383)]
# [point(303, 372) point(315, 360) point(327, 354) point(337, 357)
#  point(346, 354) point(358, 360) point(369, 371) point(359, 384)
#  point(347, 390) point(337, 391) point(327, 390) point(315, 383)]
# [point(304, 372) point(315, 361) point(327, 354) point(337, 357)
#  point(347, 354) point(359, 360) point(370, 371) point(360, 384)
#  point(348, 389) point(337, 391) point(326, 389) point(315, 383)]
# [point(303, 371) point(315, 361) point(327, 354) point(338, 357)
#  point(347, 354) point(359, 360) point(369, 370) point(360, 383)
#  point(348, 389) point(338, 390) point(327, 389) point(315, 383)]
# [point(304, 372) point(315, 361) point(327, 354) point(337, 357)
#  point(347, 354) point(359, 361) point(370, 371) point(361, 385)
#  point(349, 391) point(338, 392) point(328, 391) point(316, 385)]
# [point(303, 372) point(315, 361) point(327, 355) point(337, 358)
#  point(347, 355) point(359, 361) point(370, 372) point(360, 385)
#  point(348, 391) point(338, 392) point(327, 390) point(315, 384)]
# [point(303, 372) point(315, 361) point(327, 354) point(337, 357)
#  point(346, 354) point(359, 360) point(370, 371) point(360, 385)
#  point(348, 391) point(337, 393) point(327, 391) point(315, 385)]
# [point(303, 372) point(315, 361) point(327, 355) point(338, 358)
#  point(348, 355) point(360, 361) point(371, 372) point(361, 386)
#  point(349, 392) point(338, 393) point(327, 391) point(315, 385)]
# [point(303, 372) point(315, 361) point(328, 354) point(338, 357)
#  point(348, 354) point(360, 361) point(371, 372) point(361, 386)
#  point(349, 392) point(338, 393) point(327, 392) point(315, 385)]
# [point(303, 372) point(316, 360) point(328, 354) point(338, 357)
#  point(347, 354) point(360, 361) point(370, 372) point(361, 387)
#  point(349, 393) point(338, 393) point(328, 392) point(315, 385)]
# [point(304, 372) point(315, 361) point(328, 354) point(338, 357)
#  point(348, 354) point(361, 361) point(371, 372) point(361, 386)
#  point(349, 393) point(339, 394) point(328, 392) point(315, 385)]
# [point(304, 373) point(316, 361) point(328, 355) point(339, 358)
#  point(348, 355) point(361, 361) point(371, 372) point(361, 385)
#  point(349, 391) point(338, 392) point(327, 391) point(315, 384)]
# [point(305, 373) point(317, 363) point(329, 356) point(339, 359)
#  point(348, 356) point(360, 361) point(371, 371) point(361, 384)
#  point(349, 389) point(339, 390) point(329, 389) point(317, 384)]
# [point(305, 371) point(317, 363) point(329, 357) point(339, 360)
#  point(347, 357) point(360, 363) point(371, 371) point(360, 382)
#  point(348, 387) point(339, 388) point(329, 387) point(317, 381)]
# [point(305, 372) point(317, 364) point(329, 357) point(338, 360)
#  point(347, 357) point(359, 362) point(370, 370) point(360, 380)
#  point(348, 386) point(339, 387) point(329, 386) point(317, 382)]
# [point(304, 371) point(316, 363) point(329, 357) point(339, 360)
#  point(348, 357) point(360, 363) point(371, 371) point(360, 380)
#  point(349, 385) point(339, 386) point(328, 385) point(316, 380)]
# [point(304, 371) point(317, 363) point(329, 358) point(339, 361)
#  point(348, 358) point(360, 363) point(372, 371) point(360, 380)
#  point(349, 385) point(339, 386) point(329, 385) point(317, 380)]
# [point(304, 371) point(317, 363) point(329, 357) point(339, 360)
#  point(347, 357) point(360, 362) point(371, 370) point(360, 381)
#  point(348, 386) point(339, 387) point(329, 386) point(317, 381)]
# [point(303, 371) point(316, 363) point(329, 358) point(339, 361)
#  point(348, 358) point(360, 363) point(371, 371) point(360, 381)
#  point(349, 386) point(339, 387) point(329, 386) point(316, 381)]

# %%
test = [(1, 2), (4, 6), (2, 6), (6, 7)]

# %%
import time
import imutils

# %%
cap = cv2.VideoCapture('../Parsing/Audio/Dataset/в/возможно//0.mp4')
detector = dlib.get_frontal_face_detector()
predictor = dlib.shape_predictor('../Models/shape_predictor_68_face_landmarks.dat')
WIDTH = cap.get(3)
HEIGHT = cap.get(4)
FRAMES = cap.get(cv2.CAP_PROP_FRAME_COUNT)
detections = 0 # Количество кадров с детектированным лицом
x1_avg, x2_avg, y1_avg, y2_avg = 0, 0, 0, 0
x1_avg_landmark, x2_avg_landmark = 0, 0
y1_avg_landmark, y2_avg_landmark = 0, 0

while True:
    ret, frame = cap.read()
    if not ret:
        break
    
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    
    
    faces = detector(gray)
    for face in faces:
        print(type(face))
        detections += 1
        
        landmarks = predictor(gray, face)
        x1, y1 = face.left(), face.top()
        x2, y2 = face.right(), face.bottom()
        x1_avg += x1
        x2_avg += x2
        y1_avg += y1
        y2_avg += y2
        
        mouth_landmarks = landmarks.parts()[48:60]
        for i, landmark in enumerate(mouth_landmarks):
            x, y = landmark.x, landmark.y
            if i == 0:
                x1_avg_landmark += x
                y1_avg_landmark += y
            elif i == 6:
                x2_avg_landmark += x
                y2_avg_landmark += y
                
            cv2.circle(frame, (x, y), 2, (0, 0, 255))
        
        cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)
    
    cv2.imshow('frame', frame)
    if cv2.waitKey(1) & 0xff == ord('q'):
        break
        
    time.sleep(0.1)
        
cap.release()
cv2.destroyAllWindows()

x1_avg = int(x1_avg / detections)
x2_avg = int(x2_avg / detections)
y1_avg = int(y1_avg / detections)
y2_avg = int(y2_avg / detections)

x1_avg_landmark = int(x1_avg_landmark / detections)
x2_avg_landmark = int(x2_avg_landmark / detections)
y1_avg_landmark = int(y1_avg_landmark / detections)
y2_avg_landmark = int(y2_avg_landmark / detections)



angle = np.arctan2(y2_avg_landmark - y1_avg_landmark,
                  x2_avg_landmark - x1_avg_landmark)
angle = 180 * angle / np.pi

face = dlib.rectangle(x1_avg, y1_avg, x2_avg, y2_avg)


x_min, y_min, x_max, y_max = 200, 300, 0, 0

cap = cv2.VideoCapture('../Parsing/Audio/Dataset/в/войти/0.mp4')
while True:
    ret, frame = cap.read()
    if not ret:
        break
        
    cv2.rectangle(frame, (x1_avg, y1_avg), 
                  (x2_avg, y2_avg), (0, 255, 255), 2)
    
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    
    landmarks = predictor(gray, face)
    mouth_landmarks = landmarks.parts()[48:60]
    for i, landmark in enumerate(mouth_landmarks):
        
        x, y = landmark.x, landmark.y
        x_min = min(x, x_min)
        x_max = max(x, x_max)
        y_min = min(y, y_min)
        y_max = max(y, y_max)
        
        cv2.circle(frame, (x, y), 2, (0, 0, 255))
        
    frame = imutils.rotate(frame, angle, 
                           center=(face.center().x, face.center().y))
    img_cropped = frame[face.top() : face.bottom(),
                       face.left() : face.right()]
    img_cropped = imutils.resize(img_cropped, width=200, height=300)
    
    cv2.imshow('frame_cropped', img_cropped)    
    cv2.imshow('frame', frame)
    
    time.sleep(1)
    if cv2.waitKey(1) & 0xff == ord('q'):
        break
        
cap.release()
cv2.destroyAllWindows()

cap = cv2.VideoCapture('../Parsing/Audio/Dataset/в/войти/0.mp4')
angle = np.arctan2(x_max - x_min, y_max - y_min)

while True:
    ret, frame = cap.read()
    if not ret:
        break
        
    rot_frame = imutils.rotate(frame, angle)
    cv2.imshow('rotated frame', rot_frame)
    
    if cv2.waitKey(1) & 0xff == ord('q'):
        break
        
    time.sleep(0.1)
        
cap.release()
cv2.destroyAllWindows()
# Out:
# <class '_dlib_pybind11.rectangle'>
# <class '_dlib_pybind11.rectangle'>
# <class '_dlib_pybind11.rectangle'>
# <class '_dlib_pybind11.rectangle'>
# <class '_dlib_pybind11.rectangle'>
# <class '_dlib_pybind11.rectangle'>
# <class '_dlib_pybind11.rectangle'>
# <class '_dlib_pybind11.rectangle'>
# <class '_dlib_pybind11.rectangle'>
# <class '_dlib_pybind11.rectangle'>

# %%
x_max - x_min
# Out:
# 246

# %%
y_max - y_min
# Out:
# 23

# %%
np.tan(1.47)
# Out:
# 9.88737489198555

# %%
a = np.arctan2(y_max - y_min, x_max - x_min)

# %%
180 * a / np.pi
# Out:
# 4.647970691387034

# %%
imutils.rotate?

# %%
class Chunck:
    def __init__(self, video_path, shape_predictor_path, size=(300, 200)):
        self.path = video_path
        self.size = size
        self.detector = dlib.get_frontal_face_detector()
        self.predictor = dlib.shape_predictor(shape_predictor_path)
        self.x1_avg_face, self.x2_avg_face = 0, 0
        self.y1_avg_face, self.y2_avg_face = 0, 0
        self.x1_avg_landmark, self.x2_avg_landmark = 0, 0
        self.y1_avg_landmark, self.y2_avg_landmark = 0, 0
        self.angle = 0
        
        cap = cv2.VideoCapture(video_path)
        self.WIDTH = cap.get(3)
        self.HEIGHT = cap.get(4)
        self.FRAME_COUNT = cap.get(cv2.CAP_PROP_FRAME_COUNT)
     
    
    def prepare(self):
        """
        Метод для подготовки нахождения координат лица, лендмарков
        и вращения, чтобы губы были параллельно оси Ox
        """
        
        cap = cv2.VideoCapture(self.path)
        detections = 0
        self.x1_avg_face, self.x2_avg_face = 0, 0
        self.y1_avg_face, self.y2_avg_face = 0, 0
        self.x1_avg_landmark, self.x2_avg_landmark = 0, 0
        self.y1_avg_landmark, self.y2_avg_landmark = 0, 0
        
        while True:
            ret, frame = cap.read()
            if not ret:
                break
                
            gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
            faces = detector(gray)
            
                
            for face in faces:
                detections += 1
                self.x1_avg_face += face.left()
                self.x2_avg_face += face.right()
                self.y1_avg_face += face.top()
                self.y2_avg_face += face.bottom()
                
                landmarks = predictor(gray, face)
                mouth_landmarks = landmarks.parts()[48:60]
                
                for i, landmark in enumerate(mouth_landmarks):
                    x, y = landmark.x, landmark.y
                    if i == 0:
                        self.x1_avg_landmark += x
                        self.y1_avg_landmark += y
                    elif i == 6:
                        self.x2_avg_landmark += x
                        self.y2_avg_landmark += y
                        
            
            if cv2.waitKey(1) & 0xff == ord('q'):
                break
        
        cap.release()
        
        self.x1_avg_face = int(self.x1_avg_face / detections)
        self.x2_avg_face = int(self.x2_avg_face / detections)
        self.y1_avg_face = int(self.y1_avg_face / detections)
        self.y2_avg_face = int(self.y2_avg_face / detections)
        
        self.x1_avg_landmark = int(self.x1_avg_landmark / detections)
        self.x2_avg_landmark = int(self.x2_avg_landmark / detections)
        self.y1_avg_landmark = int(self.y1_avg_landmark / detections)
        self.y2_avg_landmark = int(self.y2_avg_landmark / detections)
        
        a = self.x2_avg_landmark - self.x1_avg_landmark
        b = self.y2_avg_landmark - self.y1_avg_landmark
        self.angle = 180 * np.arctan2(b, a) / np.pi
        
        self.face = dlib.rectangle(self.x1_avg_face, self.y1_avg_face,
                                  self.x2_avg_face, self.y2_avg_face)
        
    def show(self, time_sleep=0):
        cap = cv2.VideoCapture(self.path)
        
        while True:
            ret, frame = cap.read()
            if not ret:
                break
                
                 
            gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
            landmarks = predictor(gray, self.face)
            for landmark in landmarks.parts()[48:60]:
                x, y = landmark.x, landmark.y
                print(x, y)
                cv2.circle(frame, (x, y), 2, (0, 0, 255))
                
            frame = imutils.rotate(frame, self.angle, center=(self.face.center().x,
                                                        self.face.center().y))
                
            frame = frame[face.top() : face.bottom(), face.left() : face.right()]
            frame = imutils.resize(frame, width=self.size[0], height=self.size[1])
            cv2.imshow('chunk', frame)
            time.sleep(time_sleep)
            
            if cv2.waitKey(1) & 0xff == ord('q'):
                break
                
        cap.release()
        cv2.destroyAllWindows()

# %%
chunck = Chunck('../Parsing/Audio/Dataset/в/возможно/0.mp4', '../Models/shape_predictor_68_face_landmarks.dat')

# %%
chunck.prepare()

# %%
chunck.show(0.1)
# Out:
# 401 142
# 405 140
# 408 140
# 411 141
# 414 141
# 419 144
# 424 148
# 417 150
# 412 150
# 409 149
# 406 148
# 403 146
# 400 143
# 403 141
# 408 140
# 410 142
# 414 142
# 419 145
# 424 149
# 417 152
# 412 152
# 408 151
# 405 150
# 402 147
# 400 143
# 403 142
# 407 142
# 410 143
# 413 143
# 418 146
# 423 150
# 416 153
# 411 153
# 408 152
# 405 151
# 402 149
# 400 144
# 404 143
# 408 142
# 411 144
# 414 144
# 418 146
# 423 150
# 417 152
# 412 152
# 409 152
# 406 151
# 402 148
# 402 145
# 405 143
# 409 143
# 412 144
# 414 144
# 419 146
# 423 150
# 417 152
# 413 152
# 410 152
# 407 150
# 404 149
# 402 145
# 406 143
# 409 143
# 412 144
# 414 144
# 418 146
# 423 150
# 417 152
# 413 152
# 410 151
# 407 150
# 404 148
# 403 145
# 406 143
# 409 143
# 412 144
# 414 144
# 418 147
# 423 150
# 417 153
# 413 153
# 410 152
# 407 151
# 405 149
# 404 145
# 406 143
# 410 142
# 412 143
# 415 143
# 419 146
# 424 150
# 418 153
# 413 153
# 410 153
# 408 152
# 405 149
# 404 145
# 406 142
# 411 141
# 413 142
# 416 142
# 421 145
# 425 150
# 419 153
# 414 154
# 411 154
# 408 153
# 405 150
# 403 144
# 406 141
# 411 140
# 413 141
# 416 141
# 421 144
# 426 149
# 420 152
# 415 153
# 412 153
# 408 152
# 405 149
# 404 143
# 407 141
# 411 140
# 414 141
# 417 141
# 422 144
# 427 149
# 421 153
# 416 154
# 412 153
# 409 152
# 406 149
# 404 144
# 408 141
# 412 140
# 415 142
# 418 142
# 423 145
# 427 149
# 422 153
# 416 154
# 413 153
# 410 152
# 406 149
# 404 144
# 408 143
# 412 142
# 415 144
# 418 143
# 423 146
# 428 150
# 421 152
# 416 153
# 413 152
# 410 151
# 406 148
# 404 145
# 408 143
# 412 143
# 415 144
# 418 144
# 423 147
# 428 150
# 421 152
# 416 152
# 413 152
# 410 151
# 406 149
# 404 145
# 408 144
# 412 143
# 414 145
# 417 144
# 422 147
# 427 150
# 421 152
# 416 153
# 413 153
# 410 151
# 406 149
# 404 145
# 407 144
# 412 143
# 414 145
# 417 144
# 422 147
# 427 151
# 421 153
# 415 153
# 412 153
# 410 152
# 406 149

# %%
# Out:
# 12.094757077012103

# %%
chunck.face
# Out:
# rectangle(243,59,288,104)
